# %% [markdown]
# <a href="https://colab.research.google.com/github/scomarae/SkillBox/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%223_11_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%8F%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Домашняя работа
#
# **Задание простого уровня** Мы говорили, что метрики качества нужны, чтобы сравнивать различные модели между собой. В задаче полиномиальной регрессии реализуйте код для выбора лучшей степени полиному:
#
# * возьмите все степени от 1 до 10 по порядку, без пропусков.
# * найдите степень полинома, где будет лучший r2-score
# * напишите код, который выводит самую подходящую степень полинома и соответствующий ей скор
#
# Эта процедура называется Grid Search и помогает найти лучшие параметры для модели.
#
# Обучите лучшую модель и сделайте predict

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %% [markdown]
# Взяла точки, сгенерированные на одном из прошлых уроков (в задании не сказано, с какими данными работать)

# %%
x = np.linspace(1, 10, num=10)
y = [
    1.5,
    2.5,
    3,
    4.5,
    12,
    6.7,
    7,
    8.5,
    14,
    7
]

# %% [markdown]
# Немного измененные функции для генерации степени и предсказания из прошлых уроков:

# %%
def generate_degrees(source_data: list, degree: int):
    """Функция, которая принимает на вход одномерный массив, а возвращает n-мерный

    Для каждой степени от 1 до  degree возводим x в эту степень
    """
    return np.array([
          source_data**n for n in range(1, degree + 1)
    ]).T

# %%
degree = 2

X = generate_degrees(x, degree)
X
# Out:
# array([[  1.,   1.],
#        [  2.,   4.],
#        [  3.,   9.],
#        [  4.,  16.],
#        [  5.,  25.],
#        [  6.,  36.],
#        [  7.,  49.],
#        [  8.,  64.],
#        [  9.,  81.],
#        [ 10., 100.]])

# %%
from sklearn.metrics import r2_score

# %%
model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 2 r2 0.592

# %%
degree = 3

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 3 r2 0.606

# %%
degree = 4

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 4 r2 0.609

# %%
degree = 4

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 4 r2 0.609

# %%
degree = 5

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 5 r2 0.748

# %%
degree = 6

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 6 r2 0.900

# %%
degree = 7

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 7 r2 0.907

# %%
degree = 8

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 8 r2 0.916

# %%
degree = 9

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 9 r2 1.000

# %%
degree = 10

X = generate_degrees(x, degree)

model = LinearRegression().fit(X, y)
y_pred = model.predict(X)
error = r2_score(y, y_pred)
print("Степень полинома %d r2 %.3f" % (degree, error))
plt.scatter(x, y, 40, 'g', 'o', alpha=0.8, label='data')
plt.plot(x, y_pred)
# Out:
# Степень полинома 10 r2 1.000

# %% [markdown]
# На последних степениях r2score уже равен 1. Это нехорошо, т.к. модель теряет обобщающую способность и просто проходит по точкам.

# %% [markdown]
# **Задание среднего уровня** Напишите класс для обучения модели, который содержит:
#
# * функцию `.fit(X, y)` , которая принимает на вход массив фичей `X`, массив таргетов `y` и обучает коэффициенты регрессии. Код для обучения взять из первого урока модуля *Постановка ML задачи линейной регрессии*
# * функцию `.predict(X)`, которая по массиву фичей `X` возвращает массив предсказаний `y`
#
# Нужно использовать код для аналитически вычисляемых коэффициентов.
#
# Это задание позволит понять, как работает линейная регрессия "внутри" библиотечной реализации.

# %%
x = np.linspace(1, 10, num=10)
y = [
    1.5,
    2.5,
    3,
    4.5,
    12,
    6.7,
    7,
    8.5,
    14,
    7
]

# %%
from numpy.linalg import inv

# %%
class CustomLinearReg:

  def __init__(self):
      self.w1=None
      self.w2=None

  def fit(self, X, y):
      X_T_X = (X.T).dot(X)
      X_T_X_inverted = inv(X_T_X)
      w = X_T_X_inverted.dot(X.T).dot(y)
      self.w1, self.w2 = w[0][0], w[1][0]
      return self

  def predict(self, X):
      pass

# %% [markdown]
# **Задание высокого уровня**
#
# 1. разделите датасет с домами Бостона из Урока 2 (таргет и фичи) на две части: в одной части 80% датасета (назовём train) в другой 20% (назовём valid) с помощью функции `train_test_split` из библиотеки `sklearn`
# 1. обучите модель только на train датасете
# 1. постройте предсказания valid датасете
# 1. Посчитайте  `r2 score` на валидационном сете
#
# После этого примените к обеим датасетам z-преобразование и повторите шаги 2-4. Как изменилась метрика r2?
#
# Это задание поможет понять, как валидировать линейную регрессию (и другие модели) на отложенной выборке.

# %%
from sklearn.datasets import fetch_california_housing


from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()

# %%
X_train, X_valid, y_train, y_valid = train_test_split(housing.data, housing.target, test_size=0.2, train_size=0.8)

# %% [markdown]
# Обучение на train-датасете:

# %%
reg = LinearRegression().fit(X_train, y_train)

# %% [markdown]
# Предсказание на valid-датасете:

# %%
y_valid_pred = reg.predict(X_valid)

# %% [markdown]
# Оценка r2score:

# %%
from sklearn.metrics import r2_score

r2_score(y_valid, y_valid_pred)
# Out:
# 0.5951366178340288

# %% [markdown]
# z-преобразование:

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()

X_train_transform = sc.fit_transform(X_train)
X_valid_transform = sc.transform(X_valid)

# %% [markdown]
# Обучение на преобразованном train-датасете:

# %%
reg = LinearRegression().fit(X_train_transform, y_train)

# %% [markdown]
# Предсказание на преобразованном valid-датасете:

# %%
y_valid_transform_pred = reg.predict(X_valid_transform)

# %% [markdown]
# Оценка r2score:

# %%
r2_score(y_valid, y_valid_transform_pred)
# Out:
# 0.5951366178340323
